# %%
import os
import json

# %%
with open("data/gdp.json", "r") as f:
    data = json.load(f)

print(data.keys())
# Out:
# dict_keys(['Aruba', 'Africa Eastern and Southern', 'Afghanistan', 'Africa Western and Central', 'Angola', 'Albania', 'Andorra', 'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan', 'Botswana', 'Central African Republic', 'Canada', 'Central Europe and the Baltics', 'Switzerland', 'Channel Islands', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica', 'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pac
# ...

# %%
for key in data.keys():
    c = data[key]
    print(key, list(c).count(""))
# Out:
# Aruba 26
# Africa Eastern and Southern 0
# Afghanistan 18
# Africa Western and Central 0
# Angola 20
# Albania 24
# Andorra 10
# Arab World 8
# United Arab Emirates 15
# Argentina 2
# Armenia 30
# American Samoa 40
# Antigua and Barbuda 17
# Australia 0
# Austria 0
# Azerbaijan 30
# Burundi 0
# Belgium 0
# Benin 0
# Burkina Faso 0
# Bangladesh 0
# Bulgaria 20
# Bahrain 20
# Bahamas, The 0
# Bosnia and Herzegovina 34
# Belarus 30
# Belize 0
# Bermuda 0
# Bolivia 0
# Brazil 0
# Barbados 14
# Brunei Darussalam 5
# Bhutan 20
# Botswana 0
# Central African Republic 0
# Canada 0
# Central Europe and the Baltics 30
# Switzerland 10
# Channel Islands 38
# Chile 0
# China 0
# Cote d'Ivoire 0
# Cameroon 0
# Congo, Dem. Rep. 0
# Congo, Rep. 0
# Colombia 0
# Comoros 20
# Cabo Verde 20
# Costa Rica 0
# Caribbean small states 0
# Cuba 10
# Curacao 40
# Cayman Islands 40
# Cyprus 15
# Czechia 30
# Germany 10
# Djibouti 26
# Dominica 17
# Denmark 6
# Dominican Republic 0
# Algeria 0
# ...
